# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import torch.nn.functional as F
from tabulate import tabulate

# === Model definition ===
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class FPFNPenalizedCELoss(nn.Module):
    def __init__(self, fn_weight=3.0, fp_weight=3.0):
        super().__init__()
        self.fn_weight = fn_weight
        self.fp_weight = fp_weight
        self.ce = nn.CrossEntropyLoss(reduction='none')  # per-sample loss

    def forward(self, outputs, targets):
        # outputs: [batch_size, num_classes]
        # targets: [batch_size]
        loss = self.ce(outputs, targets)  # [batch_size]
        preds = torch.argmax(outputs, dim=1)

        # False Negatives: predicted 0, actual 1
        fn_mask = (preds == 0) & (targets == 1)
        loss[fn_mask] *= self.fn_weight

        # False Positives: predicted 1, actual 0
        fp_mask = (preds == 1) & (targets == 0)
        loss[fp_mask] *= self.fp_weight

        return loss.mean()

class UNetClassifier(nn.Module):
    def __init__(self, in_channels=3, num_classes=2, features=[32, 64, 128, 256, 512]):
        super(UNetClassifier, self).__init__()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Linear(features[-1]*2, num_classes)

    def forward(self, x):
        for down in self.downs:
            x = down(x)
            x = self.pool(x)
        x = self.bottleneck(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# === Device config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Transform and Data Loaders ===
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees=10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0])
])

val_test_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.0, 0.0, 0.0], std=[1.0, 1.0, 1.0])
])

train_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/train", transform=train_transform)
val_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/val", transform=val_test_transform)
test_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/test", transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# === Dataset Info ===
print("Classes:", train_dataset.classes)
print("Class-to-idx:", train_dataset.class_to_idx)
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(val_dataset)}")
print(f"Number of test images: {len(test_dataset)}")

# === Model, Loss, Optimizer ===
model = UNetClassifier(in_channels=3, num_classes=2).to(device)
class_weights = torch.tensor([1.0, 5.0], dtype=torch.float).to(device)
criterion = FPFNPenalizedCELoss(fn_weight=3.0, fp_weight=3.0)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
print("Using device:", device)
print("Class weights:", class_weights)

# === Training + Validation ===
def train(num_epochs):
    print("\n[Starting Training]")
    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # Validation
        model.eval()
        val_preds, val_labels = [], []
        val_running_loss = 0.0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * images.size(0)

                _, preds = torch.max(outputs, 1)
                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        epoch_val_loss = val_running_loss / len(val_loader.dataset)
        val_losses.append(epoch_val_loss)

        acc = accuracy_score(val_labels, val_preds)
        print(f"Epoch [{epoch+1}/{num_epochs}] - Train Loss: {epoch_train_loss:.4f} - Val Loss: {epoch_val_loss:.4f} - Val Acc: {acc:.4f}")
        if (epoch + 1) % 1 == 0:
            cm = confusion_matrix(val_labels, val_preds)
            disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.classes)

            fig, ax = plt.subplots(figsize=(5, 5))
            disp.plot(ax=ax, cmap='Blues', colorbar=True)
            plt.title(f"Confusion Matrix - Epoch {epoch + 1}")
            plt.show()

        # Free up memory
        torch.cuda.empty_cache()

    # Plot training and validation loss
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss', marker='o')
    plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', marker='x')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Save model
    torch.save(model.state_dict(), "unet_classifier.pth")
    print("Model saved as 'unet_classifier.pth'")

# === Testing ===
def test():
    print("\n[Before Testing]")
    print(f"Test dataset contains {len(test_dataset)} images.")

    model.eval()
    all_preds, all_labels = [], []
    mislabelled_images = []

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Find misclassified images in the current batch
            for i in range(images.size(0)):
                true_label = labels[i].item()
                pred_label = preds[i].item()
                if true_label != pred_label:
                    # Compute the index of the image in the dataset
                    dataset_index = idx * test_loader.batch_size + i
                    image_path, _ = test_dataset.samples[dataset_index]
                    mislabelled_images.append((image_path, true_label, pred_label))

    acc = accuracy_score(all_labels, all_preds)
    print(f"Test Accuracy: {acc:.4f}")

    # === Confusion Matrix ===
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.classes)

    fig, ax = plt.subplots(figsize=(6, 6))
    disp.plot(ax=ax, cmap='Blues', colorbar=True)
    plt.title("Confusion Matrix - Test Set")
    plt.show()

    # === Print mislabelled filenames ===
    print(f"\nTotal mislabelled images: {len(mislabelled_images)}")
    for path, true_label, pred_label in mislabelled_images:
        print(f"Mislabelled: {path} | True: {train_dataset.classes[true_label]} | Pred: {train_dataset.classes[pred_label]}")

# === Run Training + Save ===
print(f"Training with FN weight = {criterion.fn_weight}, FP weight = {criterion.fp_weight}")
train(num_epochs=100)

# === Show parameter ===
def print_training_config():
    model_name = model.__class__.__name__
    features = model.bottleneck.conv[0].in_channels // 2  # estimate base feature
    feature_list = [features * (2**i) for i in range(5)]  # approx. reconstruction

    config = [
        ["Model Architecture", model_name],
        ["Input Channels", model.downs[0].conv[0].in_channels],
        ["Output Classes", model.classifier.out_features],
        ["Feature Sizes", str(feature_list)],
        ["Loss Function", criterion.__class__.__name__],
        ["False Negative Weight", criterion.fn_weight],
        ["False Positive Weight", criterion.fp_weight],
        ["Optimizer", optimizer.__class__.__name__],
        ["Learning Rate", optimizer.param_groups[0]['lr']],
        ["Weight Decay", optimizer.param_groups[0]['weight_decay']],
        ["Batch Size", train_loader.batch_size],
        ["Epochs", num_epochs if 'num_epochs' in globals() else "Defined later"],
        ["Train Augmentations", ', '.join([t.__class__.__name__ for t in train_transform.transforms])],
        ["Val/Test Transforms", ', '.join([t.__class__.__name__ for t in val_test_transform.transforms])],
        ["Normalization Mean", str(train_transform.transforms[-1].mean)],
        ["Normalization Std", str(train_transform.transforms[-1].std)],
        ["Train Dataset Path", train_dataset.root],
        ["Val Dataset Path", val_dataset.root],
        ["Test Dataset Path", test_dataset.root],
        ["Device", str(device)],
        ["Model Save Path", "unet_classifier.pth"]
    ]

    print("\n[ Training Configuration Summary ]")
    print(tabulate(config, headers=["Parameter", "Value"], tablefmt="fancy_grid"))

print_training_config()

# === Load and Test ===
model.load_state_dict(torch.load("unet_classifier.pth"))
model.to(device)
print("Model loaded from 'unet_classifier.pth'")
test()
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Class-to-idx: {'NORMAL': 0, 'PNEUMONIA': 1}
# Number of training images: 3302
# Number of validation images: 30
# Number of test images: 270
# Using device: cuda
# Class weights: tensor([1., 5.], device='cuda:0')
# Training with FN weight = 3.0, FP weight = 3.0
#
# [Starting Training]
# Epoch [1/100] - Train Loss: 1.0105 - Val Loss: 2.6888 - Val Acc: 0.5667
# Epoch [2/100] - Train Loss: 0.7161 - Val Loss: 1.6533 - Val Acc: 0.7000
# Epoch [3/100] - Train Loss: 0.6625 - Val Loss: 0.3574 - Val Acc: 0.9333
# Epoch [4/100] - Train Loss: 0.5529 - Val Loss: 0.2003 - Val Acc: 1.0000
# Epoch [5/100] - Train Loss: 0.4944 - Val Loss: 0.1790 - Val Acc: 1.0000
# Epoch [6/100] - Train Loss: 0.4722 - Val Loss: 1.0642 - Val Acc: 0.7667
# Epoch [7/100] - Train Loss: 0.4786 - Val Loss: 0.5596 - Val Acc: 0.8667
# Epoch [8/100] - Train Loss: 0.4206 - Val Loss: 0.6092 - Val Acc: 0.8333
# Epoch [9/100] - Train Loss: 0.4342 - Val Loss: 0.3001 - Val Acc: 0.9333
# Epoch [10/100] - Train Loss: 0.4306 - Val Loss: 0.2428 - Val Acc: 0.9667
# Epoch [11/100] - Train Loss: 0.3944 - Val Loss: 0.3721 - Val Acc: 0.9333
# Epoch [12/100] - Train Loss: 0.3858 - Val Loss: 0.1888 - Val Acc: 0.9667
# Epoch [13/100] - Train Loss: 0.3799 - Val Loss: 0.5371 - Val Acc: 0.8333
# Epoch [14/100] - Train Loss: 0.3832 - Val Loss: 0.1267 - Val Acc: 1.0000
# Epoch [15/100] - Train Loss: 0.3343 - Val Loss: 0.1007 - Val Acc: 1.0000
# Epoch [16/100] - Train Loss: 0.3327 - Val Loss: 0.3197 - Val Acc: 0.9333
# Epoch [17/100] - Train Loss: 0.3496 - Val Loss: 0.3239 - Val Acc: 0.9333
# Epoch [18/100] - Train Loss: 0.3063 - Val Loss: 0.3988 - Val Acc: 0.9000
# Epoch [19/100] - Train Loss: 0.3062 - Val Loss: 0.1737 - Val Acc: 0.9667
# Epoch [20/100] - Train Loss: 0.3277 - Val Loss: 0.2738 - Val Acc: 0.9333
# Epoch [21/100] - Train Loss: 0.2942 - Val Loss: 0.0683 - Val Acc: 1.0000
# Epoch [22/100] - Train Loss: 0.2884 - Val Loss: 0.1993 - Val Acc: 0.9667
# Epoch [23/100] - Train Loss: 0.2772 - Val Loss: 0.0585 - Val Acc: 1.0000
# Epoch [24/100] - Train Loss: 0.2800 - Val Loss: 0.0966 - Val Acc: 1.0000
# Epoch [25/100] - Train Loss: 0.2635 - Val Loss: 0.0938 - Val Acc: 1.0000
# Epoch [26/100] - Train Loss: 0.2922 - Val Loss: 0.0957 - Val Acc: 1.0000
# Epoch [27/100] - Train Loss: 0.2456 - Val Loss: 0.0795 - Val Acc: 1.0000
# Epoch [28/100] - Train Loss: 0.2578 - Val Loss: 0.1728 - Val Acc: 0.9667
# Epoch [29/100] - Train Loss: 0.2321 - Val Loss: 0.1199 - Val Acc: 0.9667
# Epoch [30/100] - Train Loss: 0.2558 - Val Loss: 0.0705 - Val Acc: 1.0000
# Epoch [31/100] - Train Loss: 0.2601 - Val Loss: 0.3112 - Val Acc: 0.9000
# Epoch [32/100] - Train Loss: 0.2329 - Val Loss: 0.0710 - Val Acc: 1.0000
# Epoch [33/100] - Train Loss: 0.2057 - Val Loss: 0.4015 - Val Acc: 0.9000
# Epoch [34/100] - Train Loss: 0.2260 - Val Loss: 0.0922 - Val Acc: 1.0000
# Epoch [35/100] - Train Loss: 0.2146 - Val Loss: 0.0792 - Val Acc: 1.0000
# Epoch [36/100] - Train Loss: 0.2226 - Val Loss: 0.1600 - Val Acc: 0.9667
# Epoch [37/100] - Train Loss: 0.2027 - Val Loss: 0.0892 - Val Acc: 1.0000
# Epoch [38/100] - Train Loss: 0.2213 - Val Loss: 0.0728 - Val Acc: 1.0000
# Epoch [39/100] - Train Loss: 0.2053 - Val Loss: 0.3253 - Val Acc: 0.9000
# Epoch [40/100] - Train Loss: 0.2201 - Val Loss: 0.3552 - Val Acc: 0.9333
# Epoch [41/100] - Train Loss: 0.2018 - Val Loss: 0.3711 - Val Acc: 0.9000
# Epoch [42/100] - Train Loss: 0.2196 - Val Loss: 0.1619 - Val Acc: 0.9667
# Epoch [43/100] - Train Loss: 0.1799 - Val Loss: 0.1671 - Val Acc: 0.9667
# Epoch [44/100] - Train Loss: 0.1818 - Val Loss: 0.3181 - Val Acc: 0.9333
# Epoch [45/100] - Train Loss: 0.2034 - Val Loss: 0.0652 - Val Acc: 1.0000
# Epoch [46/100] - Train Loss: 0.1917 - Val Loss: 0.2329 - Val Acc: 0.9333
# Epoch [47/100] - Train Loss: 0.1637 - Val Loss: 0.0526 - Val Acc: 1.0000
# Epoch [48/100] - Train Loss: 0.1929 - Val Loss: 0.1238 - Val Acc: 0.9667
# Epoch [49/100] - Train Loss: 0.1676 - Val Loss: 0.2861 - Val Acc: 0.9333
# Epoch [50/100] - Train Loss: 0.1910 - Val Loss: 0.2061 - Val Acc: 0.9333
# Epoch [51/100] - Train Loss: 0.1754 - Val Loss: 0.1928 - Val Acc: 0.9667
# Epoch [52/100] - Train Loss: 0.1884 - Val Loss: 0.2333 - Val Acc: 0.9667
# Epoch [53/100] - Train Loss: 0.1596 - Val Loss: 0.2766 - Val Acc: 0.9667
# Epoch [54/100] - Train Loss: 0.1805 - Val Loss: 0.1727 - Val Acc: 0.9667
# Epoch [55/100] - Train Loss: 0.1709 - Val Loss: 0.0730 - Val Acc: 1.0000
# Epoch [56/100] - Train Loss: 0.1437 - Val Loss: 0.2250 - Val Acc: 0.9333
# Epoch [57/100] - Train Loss: 0.1567 - Val Loss: 0.1402 - Val Acc: 0.9667
# Epoch [58/100] - Train Loss: 0.1399 - Val Loss: 0.1699 - Val Acc: 0.9667
# Epoch [59/100] - Train Loss: 0.1347 - Val Loss: 0.1164 - Val Acc: 0.9667
# Epoch [60/100] - Train Loss: 0.1509 - Val Loss: 0.1935 - Val Acc: 0.9667
# Epoch [61/100] - Train Loss: 0.1436 - Val Loss: 0.1553 - Val Acc: 0.9667
# Epoch [62/100] - Train Loss: 0.1457 - Val Loss: 0.1339 - Val Acc: 0.9667
# Epoch [63/100] - Train Loss: 0.1460 - Val Loss: 0.2681 - Val Acc: 0.9333
# Epoch [64/100] - Train Loss: 0.1293 - Val Loss: 0.1725 - Val Acc: 0.9667
# Epoch [65/100] - Train Loss: 0.1606 - Val Loss: 0.2053 - Val Acc: 0.9667
# Epoch [66/100] - Train Loss: 0.1328 - Val Loss: 0.2882 - Val Acc: 0.9333
# Epoch [67/100] - Train Loss: 0.1320 - Val Loss: 0.1566 - Val Acc: 0.9667
# Epoch [68/100] - Train Loss: 0.1380 - Val Loss: 0.1528 - Val Acc: 0.9667
# Epoch [69/100] - Train Loss: 0.1052 - Val Loss: 0.1679 - Val Acc: 0.9667
# Epoch [70/100] - Train Loss: 0.1387 - Val Loss: 0.0957 - Val Acc: 0.9667
# Epoch [71/100] - Train Loss: 0.1247 - Val Loss: 0.2251 - Val Acc: 0.9667
# Epoch [72/100] - Train Loss: 0.1199 - Val Loss: 0.1647 - Val Acc: 0.9667
# Epoch [73/100] - Train Loss: 0.1176 - Val Loss: 0.2197 - Val Acc: 0.9333
# Epoch [74/100] - Train Loss: 0.1151 - Val Loss: 0.2604 - Val Acc: 0.9667
# Epoch [75/100] - Train Loss: 0.1236 - Val Loss: 0.1604 - Val Acc: 0.9667
# Epoch [76/100] - Train Loss: 0.1317 - Val Loss: 0.1561 - Val Acc: 0.9667
# Epoch [77/100] - Train Loss: 0.1043 - Val Loss: 0.2925 - Val Acc: 0.9667
# Epoch [78/100] - Train Loss: 0.1166 - Val Loss: 0.4836 - Val Acc: 0.9000
# Epoch [79/100] - Train Loss: 0.1137 - Val Loss: 0.0486 - Val Acc: 1.0000
# Epoch [80/100] - Train Loss: 0.1063 - Val Loss: 0.0993 - Val Acc: 0.9667
# Epoch [81/100] - Train Loss: 0.0912 - Val Loss: 0.4197 - Val Acc: 0.9333
# Epoch [82/100] - Train Loss: 0.1113 - Val Loss: 0.1323 - Val Acc: 0.9667
# Epoch [83/100] - Train Loss: 0.1000 - Val Loss: 0.2473 - Val Acc: 0.9667
# Epoch [84/100] - Train Loss: 0.1141 - Val Loss: 0.2914 - Val Acc: 0.9333
# Epoch [85/100] - Train Loss: 0.0881 - Val Loss: 0.1156 - Val Acc: 0.9667
# Epoch [86/100] - Train Loss: 0.1151 - Val Loss: 0.2768 - Val Acc: 0.9333
# Epoch [87/100] - Train Loss: 0.0987 - Val Loss: 0.3782 - Val Acc: 0.9333
# Epoch [88/100] - Train Loss: 0.0993 - Val Loss: 0.2965 - Val Acc: 0.9333
# Epoch [89/100] - Train Loss: 0.0845 - Val Loss: 0.3122 - Val Acc: 0.9333
# Epoch [90/100] - Train Loss: 0.0944 - Val Loss: 0.3101 - Val Acc: 0.9667
# Epoch [91/100] - Train Loss: 0.1217 - Val Loss: 0.2448 - Val Acc: 0.9667
# Epoch [92/100] - Train Loss: 0.0726 - Val Loss: 0.5177 - Val Acc: 0.9667
# Epoch [93/100] - Train Loss: 0.1015 - Val Loss: 0.3033 - Val Acc: 0.9667
# Epoch [94/100] - Train Loss: 0.0988 - Val Loss: 0.2552 - Val Acc: 0.9667
# Epoch [95/100] - Train Loss: 0.0743 - Val Loss: 0.0334 - Val Acc: 1.0000
# Epoch [96/100] - Train Loss: 0.0717 - Val Loss: 0.6068 - Val Acc: 0.9333
# Epoch [97/100] - Train Loss: 0.0921 - Val Loss: 0.2559 - Val Acc: 0.9333
# Epoch [98/100] - Train Loss: 0.0866 - Val Loss: 0.0337 - Val Acc: 1.0000
# Epoch [99/100] - Train Loss: 0.0774 - Val Loss: 0.3265 - Val Acc: 0.9333
# Epoch [100/100] - Train Loss: 0.0694 - Val Loss: 0.3631 - Val Acc: 0.9333
# Model saved as 'unet_classifier.pth'
#
# [ Training Configuration Summary ]
# ╒═══════════════════════╤═══════════════════════════════════════════════════════════════════╕
# │ Parameter             │ Value                                                             │
# ╞═══════════════════════╪═══════════════════════════════════════════════════════════════════╡
# │ Model Architecture    │ UNetClassifier                                                    │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Input Channels        │ 3                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Output Classes        │ 2                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Feature Sizes         │ [256, 512, 1024, 2048, 4096]                                      │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Loss Function         │ FPFNPenalizedCELoss                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ False Negative Weight │ 3.0                                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ False Positive Weight │ 3.0                                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Optimizer             │ Adam                                                              │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Learning Rate         │ 0.001                                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Weight Decay          │ 1e-05                                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Batch Size            │ 4                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Epochs                │ Defined later                                                     │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Train Augmentations   │ Resize, RandomHorizontalFlip, RandomRotation, ToTensor, Normalize │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Val/Test Transforms   │ Resize, ToTensor, Normalize                                       │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Normalization Mean    │ [0.0, 0.0, 0.0]                                                   │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Normalization Std     │ [1.0, 1.0, 1.0]                                                   │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Train Dataset Path    │ /home/bay/codes/unet/xray/train                                   │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Val Dataset Path      │ /home/bay/codes/unet/xray/val                                     │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Test Dataset Path     │ /home/bay/codes/unet/xray/test                                    │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Device                │ cuda                                                              │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Model Save Path       │ unet_classifier.pth                                               │
# ╘═══════════════════════╧═══════════════════════════════════════════════════════════════════╛
# Model loaded from 'unet_classifier.pth'
#
# [Before Testing]
# Test dataset contains 270 images.
# Test Accuracy: 0.9556
# Total mislabelled images: 12
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_12.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_14.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_17.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_18.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_19.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_25.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_4.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/NORMAL/NORMAL_6.png | True: NORMAL | Pred: PNEUMONIA
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_18.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_29.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_73.png | True: PNEUMONIA | Pred: NORMAL

# %%
from itertools import product
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score

# Define your grid
param_grid = {
    'lr': [1e-3, 1e-4],
    'weight_decay': [0, 1e-5],
    'batch_size': [4, 8]
}

# Get all combinations
all_combinations = list(product(param_grid['lr'], param_grid['weight_decay'], param_grid['batch_size']))

# Example loop over hyperparameter combinations
best_acc = 0.0
best_params = None

for lr, wd, batch_size in all_combinations:
    print(f"\nTrying lr={lr}, weight_decay={wd}, batch_size={batch_size}")

    # Create new model instance
    model = UNetClassifier(in_channels=3, num_classes=2).to(device)

    # Create optimizer with current hyperparams
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    # Data loaders (re-create with batch_size)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # === Train ===
    model.train()
    for epoch in range(3):  # Use fewer epochs for search speed
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = nn.CrossEntropyLoss()(outputs, labels)
            loss.backward()
            optimizer.step()

    # === Validate ===
    model.eval()
    val_preds, val_labels = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            val_preds.extend(preds.cpu().numpy())
            val_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(val_labels, val_preds)
    print(f"Validation Accuracy: {acc:.4f}")

    if acc > best_acc:
        best_acc = acc
        best_params = {'lr': lr, 'weight_decay': wd, 'batch_size': batch_size}

print(f"\nBest Hyperparameters: {best_params}, Accuracy: {best_acc:.4f}")
# Out:
# Trying lr=0.001, weight_decay=0, batch_size=4
# Validation Accuracy: 0.5625
#
# Trying lr=0.001, weight_decay=0, batch_size=8
# Validation Accuracy: 0.6875
#
# Trying lr=0.001, weight_decay=1e-05, batch_size=4
# Validation Accuracy: 0.8750
#
# Trying lr=0.001, weight_decay=1e-05, batch_size=8
# Validation Accuracy: 0.5625
#
# Trying lr=0.0001, weight_decay=0, batch_size=4
# Validation Accuracy: 0.6250
#
# Trying lr=0.0001, weight_decay=0, batch_size=8
# Validation Accuracy: 0.5000
#
# Trying lr=0.0001, weight_decay=1e-05, batch_size=4
# Validation Accuracy: 0.5000
#
# Trying lr=0.0001, weight_decay=1e-05, batch_size=8
# Validation Accuracy: 0.6875
#
# Best Hyperparameters: {'lr': 0.001, 'weight_decay': 1e-05, 'batch_size': 4}, Accuracy: 0.8750

# %%
fn_weights = [1.0, 3.0, 5.0, 7.0]
fp_weights = [1.0, 2.0, 3.0, 4.0]
def train_and_validate(fn_weight, fp_weight, num_epochs=3):
    model = UNetClassifier(in_channels=3, num_classes=2).to(device)
    criterion = FPFNPenalizedCELoss(fn_weight=fn_weight, fp_weight=fp_weight)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    for epoch in range(num_epochs):
        model.train()
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Validation
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_labels, all_preds

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from tabulate import tabulate

results = []
best_f1 = 0
best_weights = (0, 0)

for fn in fn_weights:
    for fp in fp_weights:
        print(f"Testing fn_weight={fn}, fp_weight={fp}")
        labels, preds = train_and_validate(fn_weight=fn, fp_weight=fp, num_epochs=3)  # use low epochs for speed

        cm = confusion_matrix(labels, preds)
        acc = accuracy_score(labels, preds)
        f1 = f1_score(labels, preds)

        fn_count = cm[1][0]  # false negatives
        fp_count = cm[0][1]  # false positives

        results.append((fn, fp, acc, f1, fn_count, fp_count))

        if f1 > best_f1:
            best_f1 = f1
            best_weights = (fn, fp)
headers = ["FN Weight", "FP Weight", "Accuracy", "F1 Score", "False Negatives", "False Positives"]
print(tabulate(results, headers=headers, tablefmt="fancy_grid"))

print(f"\n🎯 Best Weights: FN={best_weights[0]}, FP={best_weights[1]} (F1 Score = {best_f1:.4f})")
# Out:
# Testing fn_weight=1.0, fp_weight=1.0
# Testing fn_weight=1.0, fp_weight=2.0
# Testing fn_weight=1.0, fp_weight=3.0
# Testing fn_weight=1.0, fp_weight=4.0
# Testing fn_weight=3.0, fp_weight=1.0
# Testing fn_weight=3.0, fp_weight=2.0
# Testing fn_weight=3.0, fp_weight=3.0
# Testing fn_weight=3.0, fp_weight=4.0
# Testing fn_weight=5.0, fp_weight=1.0
# Testing fn_weight=5.0, fp_weight=2.0
# Testing fn_weight=5.0, fp_weight=3.0
# Testing fn_weight=5.0, fp_weight=4.0
# Testing fn_weight=7.0, fp_weight=1.0
# Testing fn_weight=7.0, fp_weight=2.0
# Testing fn_weight=7.0, fp_weight=3.0
# Testing fn_weight=7.0, fp_weight=4.0
# ╒═════════════╤═════════════╤════════════╤════════════╤═══════════════════╤═══════════════════╕
# │   FN Weight │   FP Weight │   Accuracy │   F1 Score │   False Negatives │   False Positives │
# ╞═════════════╪═════════════╪════════════╪════════════╪═══════════════════╪═══════════════════╡
# │           1 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           2 │     0.6875 │   0.761905 │                 0 │                 5 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           3 │     0.75   │   0.75     │                 2 │                 2 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           4 │     0.625  │   0.727273 │                 0 │                 6 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           2 │     0.75   │   0.777778 │                 1 │                 3 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           3 │     0.75   │   0.8      │                 0 │                 4 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           4 │     0.5    │   0.666667 │                 0 │                 8 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           2 │     0.75   │   0.8      │                 0 │                 4 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           3 │     0.5    │   0.636364 │                 1 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           4 │     0.75   │   0.777778 │                 1 │                 3 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           1 │     0.5    │   0.666667 │                 0 │                 8 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           2 │     0.6875 │   0.761905 │                 0 │                 5 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           3 │     0.625  │   0.727273 │                 0 │                 6 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           4 │     0.5625 │   0.695652 │                 0 │                 7 │
# ╘═════════════╧═════════════╧════════════╧════════════╧═══════════════════╧═══════════════════╛
#
# 🎯 Best Weights: FN=3.0, FP=3.0 (F1 Score = 0.8000)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from tabulate import tabulate
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# === Model definition ===
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class FPFNPenalizedCELoss(nn.Module):
    def __init__(self, fn_weight=3.0, fp_weight=3.0):
        super().__init__()
        self.fn_weight = fn_weight
        self.fp_weight = fp_weight
        self.ce = nn.CrossEntropyLoss(reduction='none')  # per-sample loss

    def forward(self, outputs, targets):
        # outputs: [batch_size, num_classes]
        # targets: [batch_size]
        loss = self.ce(outputs, targets)  # [batch_size]
        preds = torch.argmax(outputs, dim=1)

        # False Negatives: predicted 0, actual 1
        fn_mask = (preds == 0) & (targets == 1)
        loss[fn_mask] *= self.fn_weight

        # False Positives: predicted 1, actual 0
        fp_mask = (preds == 1) & (targets == 0)
        loss[fp_mask] *= self.fp_weight

        return loss.mean()

class UNetClassifier(nn.Module):
    def __init__(self, in_channels=3, num_classes=2, features=[32, 64, 128, 256, 512]):
        super(UNetClassifier, self).__init__()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Linear(features[-1]*2, num_classes)

    def forward(self, x):
        for down in self.downs:
            x = down(x)
            x = self.pool(x)
        x = self.bottleneck(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# === Device config ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Transform and Data Loaders ===
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(degrees=10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_test_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/train", transform=train_transform)
val_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/val", transform=val_test_transform)
test_dataset = datasets.ImageFolder(root="/home/bay/codes/unet/xray/test", transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# === Dataset Info ===
print("Classes:", train_dataset.classes)
print("Class-to-idx:", train_dataset.class_to_idx)
print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(val_dataset)}")
print(f"Number of test images: {len(test_dataset)}")

# === Model, Loss, Optimizer ===
model = UNetClassifier(in_channels=3, num_classes=2).to(device)
class_weights = torch.tensor([1.0, 5.0], dtype=torch.float).to(device)
criterion = FPFNPenalizedCELoss(fn_weight=3.0, fp_weight=3.0)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
print("Using device:", device)
print("Class weights:", class_weights)

# === Training + Validation ===
def train(num_epochs):
    print("\n[Starting Training]")

    train_losses = []
    val_losses = []
    val_accuracies = []
    val_precisions = []
    val_recalls = []

    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        # === Validation ===
        model.eval()
        val_preds, val_labels = [], []
        val_running_loss = 0.0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * images.size(0)

                probs = F.softmax(outputs, dim=1)
                _, preds = torch.max(probs, 1)

                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        epoch_val_loss = val_running_loss / len(val_loader.dataset)
        val_losses.append(epoch_val_loss)

        acc = accuracy_score(val_labels, val_preds)
        prec = precision_score(val_labels, val_preds, zero_division=0)
        rec = recall_score(val_labels, val_preds, zero_division=0)

        val_accuracies.append(acc)
        val_precisions.append(prec)
        val_recalls.append(rec)

        print(f"Epoch [{epoch+1}/{num_epochs}] - "
              f"Train Loss: {epoch_train_loss:.4f} - "
              f"Val Loss: {epoch_val_loss:.4f} - "
              f"Val Acc: {acc:.4f} - "
              f"Prec: {prec:.4f} - "
              f"Recall: {rec:.4f}")

        # === Class Distribution Debug Output ===
        unique_preds = set(int(p) for p in val_preds)
        unique_labels = set(int(l) for l in val_labels)
        print(f"[Epoch {epoch+1}] Unique preds: {unique_preds}, Unique labels: {unique_labels}")

        # === Save the Best Model ===
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            torch.save(model.state_dict(), "best_model.pth")
            print(f"Best model updated! Saved model with val_loss = {best_val_loss:.4f}")

        # === Confusion Matrix Every 10 Epochs (only if both classes predicted) ===
        if len(unique_preds) > 1 and (epoch + 1) % 10 == 0:
            cm = confusion_matrix(val_labels, val_preds)
            disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.classes)

            fig, ax = plt.subplots(figsize=(5, 5))
            disp.plot(ax=ax, cmap='Blues', colorbar=True)
            plt.title(f"Confusion Matrix - Epoch {epoch + 1}")
            plt.show()

        torch.cuda.empty_cache()

    # === Final Metric Plotting ===
    fig, ax = plt.subplots(1, 4, figsize=(20, 4))
    ax = ax.ravel()

    metrics = {
        "Loss": (train_losses, val_losses),
        "Accuracy": (None, val_accuracies),
        "Precision": (None, val_precisions),
        "Recall": (None, val_recalls),
    }

    for i, (name, (train_values, val_values)) in enumerate(metrics.items()):
        if train_values is not None:
            ax[i].plot(train_values, label="train")
        ax[i].plot(val_values, label="val")
        ax[i].set_title(f"Model {name}")
        ax[i].set_xlabel("Epoch")
        ax[i].set_ylabel(name.lower())
        ax[i].legend()

    plt.tight_layout()
    plt.savefig("training_metrics.png")
    plt.show()
    print("Saved training metrics plot as 'training_metrics.png'")

    # === Save model at the end if the final model is best ===
    torch.save(model.state_dict(), "final_model.pth")
    print("Model saved as 'final_model.pth'")

# === Testing ===
def test():
    print("\n[Before Testing]")
    print(f"Test dataset contains {len(test_dataset)} images.")

    model.eval()
    all_preds, all_labels = [], []
    mislabelled_images = []

    with torch.no_grad():
        for idx, (images, labels) in enumerate(test_loader):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            # Apply softmax before selecting predicted class
            probs = F.softmax(outputs, dim=1)
            _, preds = torch.max(probs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Identify misclassified samples
            for i in range(images.size(0)):
                true_label = labels[i].item()
                pred_label = preds[i].item()
                if true_label != pred_label:
                    dataset_index = idx * test_loader.batch_size + i
                    image_path, _ = test_dataset.samples[dataset_index]
                    mislabelled_images.append((image_path, true_label, pred_label))

    acc = accuracy_score(all_labels, all_preds)
    prec = precision_score(all_labels, all_preds, zero_division=0)
    rec = recall_score(all_labels, all_preds, zero_division=0)

    print(f"Test Accuracy: {acc:.4f} - Precision: {prec:.4f} - Recall: {rec:.4f}")

    # === Clean print of unique classes ===
    unique_preds = set(int(p) for p in all_preds)
    unique_labels = set(int(l) for l in all_labels)
    print(f"[Test Set] Unique preds: {unique_preds}, Unique labels: {unique_labels}")

    # === Confusion Matrix ===
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=train_dataset.classes)

    fig, ax = plt.subplots(figsize=(6, 6))
    disp.plot(ax=ax, cmap='Blues', colorbar=True)
    plt.title("Confusion Matrix - Test Set")
    plt.show()

    # === Print mislabelled filenames ===
    print(f"\nTotal mislabelled images: {len(mislabelled_images)}")
    for path, true_label, pred_label in mislabelled_images:
        print(f"Mislabelled: {path} | True: {train_dataset.classes[true_label]} | Pred: {train_dataset.classes[pred_label]}")

# === Run Training + Save ===
print(f"Training with FN weight = {criterion.fn_weight}, FP weight = {criterion.fp_weight}")
train(num_epochs=100)

# === Show parameter ===
def print_training_config():
    model_name = model.__class__.__name__
    features = model.bottleneck.conv[0].in_channels // 2  # estimate base feature
    feature_list = [features * (2**i) for i in range(5)]  # approx. reconstruction

    config = [
        ["Model Architecture", model_name],
        ["Input Channels", model.downs[0].conv[0].in_channels],
        ["Output Classes", model.classifier.out_features],
        ["Feature Sizes", str(feature_list)],
        ["Loss Function", criterion.__class__.__name__],
        ["False Negative Weight", criterion.fn_weight],
        ["False Positive Weight", criterion.fp_weight],
        ["Optimizer", optimizer.__class__.__name__],
        ["Learning Rate", optimizer.param_groups[0]['lr']],
        ["Weight Decay", optimizer.param_groups[0]['weight_decay']],
        ["Batch Size", train_loader.batch_size],
        ["Epochs", num_epochs if 'num_epochs' in globals() else "Defined later"],
        ["Train Augmentations", ', '.join([t.__class__.__name__ for t in train_transform.transforms])],
        ["Val/Test Transforms", ', '.join([t.__class__.__name__ for t in val_test_transform.transforms])],
        ["Normalization Mean", str(train_transform.transforms[-1].mean)],
        ["Normalization Std", str(train_transform.transforms[-1].std)],
        ["Train Dataset Path", train_dataset.root],
        ["Val Dataset Path", val_dataset.root],
        ["Test Dataset Path", test_dataset.root],
        ["Device", str(device)],
        ["Model Save Path", "unet_classifier.pth"]
    ]

    print("\n[ Training Configuration Summary ]")
    print(tabulate(config, headers=["Parameter", "Value"], tablefmt="fancy_grid"))

print_training_config()

# === Load and Test ===
model.load_state_dict(torch.load("unet_classifier.pth"))
model.to(device)
print("Model loaded from 'unet_classifier.pth'")
test()
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Class-to-idx: {'NORMAL': 0, 'PNEUMONIA': 1}
# Number of training images: 3302
# Number of validation images: 30
# Number of test images: 270
# Using device: cuda
# Class weights: tensor([1., 5.], device='cuda:0')
# Training with FN weight = 3.0, FP weight = 3.0
#
# [Starting Training]
# Epoch [1/100] - Train Loss: 1.0939 - Val Loss: 0.4288 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 1] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.4288
# Epoch [2/100] - Train Loss: 0.7657 - Val Loss: 1.5942 - Val Acc: 0.5667 - Prec: 0.5357 - Recall: 1.0000
# [Epoch 2] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [3/100] - Train Loss: 0.6695 - Val Loss: 2.1069 - Val Acc: 0.5333 - Prec: 0.5172 - Recall: 1.0000
# [Epoch 3] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [4/100] - Train Loss: 0.5937 - Val Loss: 0.4966 - Val Acc: 0.9000 - Prec: 0.8333 - Recall: 1.0000
# [Epoch 4] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [5/100] - Train Loss: 0.5231 - Val Loss: 0.4525 - Val Acc: 0.9000 - Prec: 0.8750 - Recall: 0.9333
# [Epoch 5] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [6/100] - Train Loss: 0.4816 - Val Loss: 0.7415 - Val Acc: 0.8333 - Prec: 0.9167 - Recall: 0.7333
# [Epoch 6] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [7/100] - Train Loss: 0.4946 - Val Loss: 0.3894 - Val Acc: 0.9333 - Prec: 0.8824 - Recall: 1.0000
# [Epoch 7] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.3894
# Epoch [8/100] - Train Loss: 0.4346 - Val Loss: 0.4215 - Val Acc: 0.8667 - Prec: 0.8667 - Recall: 0.8667
# [Epoch 8] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [9/100] - Train Loss: 0.3935 - Val Loss: 0.2575 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 9] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.2575
# Epoch [10/100] - Train Loss: 0.3815 - Val Loss: 0.4100 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 10] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [11/100] - Train Loss: 0.3847 - Val Loss: 0.3678 - Val Acc: 0.8667 - Prec: 0.9231 - Recall: 0.8000
# [Epoch 11] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [12/100] - Train Loss: 0.3500 - Val Loss: 0.5286 - Val Acc: 0.8667 - Prec: 0.8667 - Recall: 0.8667
# [Epoch 12] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [13/100] - Train Loss: 0.3466 - Val Loss: 0.3685 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 13] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [14/100] - Train Loss: 0.3315 - Val Loss: 0.4661 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 14] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [15/100] - Train Loss: 0.3399 - Val Loss: 0.3523 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 15] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [16/100] - Train Loss: 0.2983 - Val Loss: 0.3013 - Val Acc: 0.9000 - Prec: 0.9286 - Recall: 0.8667
# [Epoch 16] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [17/100] - Train Loss: 0.3102 - Val Loss: 0.2406 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 17] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.2406
# Epoch [18/100] - Train Loss: 0.2745 - Val Loss: 0.2612 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 18] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [19/100] - Train Loss: 0.2884 - Val Loss: 0.3044 - Val Acc: 0.9333 - Prec: 0.8824 - Recall: 1.0000
# [Epoch 19] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [20/100] - Train Loss: 0.2841 - Val Loss: 0.2880 - Val Acc: 0.9333 - Prec: 0.8824 - Recall: 1.0000
# [Epoch 20] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [21/100] - Train Loss: 0.2759 - Val Loss: 0.4379 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 21] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [22/100] - Train Loss: 0.2639 - Val Loss: 0.1592 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 22] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.1592
# Epoch [23/100] - Train Loss: 0.2599 - Val Loss: 0.4052 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 23] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [24/100] - Train Loss: 0.2662 - Val Loss: 0.3746 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 24] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [25/100] - Train Loss: 0.2455 - Val Loss: 0.2490 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 25] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [26/100] - Train Loss: 0.2359 - Val Loss: 0.1801 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 26] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [27/100] - Train Loss: 0.2401 - Val Loss: 0.4221 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 27] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [28/100] - Train Loss: 0.2314 - Val Loss: 0.7646 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 28] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [29/100] - Train Loss: 0.2167 - Val Loss: 0.1319 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 29] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.1319
# Epoch [30/100] - Train Loss: 0.2190 - Val Loss: 0.1111 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 30] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.1111
# Epoch [31/100] - Train Loss: 0.2075 - Val Loss: 0.5527 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 31] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [32/100] - Train Loss: 0.2087 - Val Loss: 0.5917 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 32] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [33/100] - Train Loss: 0.1885 - Val Loss: 0.0839 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 33] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.0839
# Epoch [34/100] - Train Loss: 0.2242 - Val Loss: 0.3512 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 34] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [35/100] - Train Loss: 0.2096 - Val Loss: 0.4032 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 35] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [36/100] - Train Loss: 0.1979 - Val Loss: 0.4175 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 36] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [37/100] - Train Loss: 0.1918 - Val Loss: 0.1043 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 37] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [38/100] - Train Loss: 0.1757 - Val Loss: 0.3669 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 38] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [39/100] - Train Loss: 0.2095 - Val Loss: 0.2690 - Val Acc: 0.9333 - Prec: 0.8824 - Recall: 1.0000
# [Epoch 39] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [40/100] - Train Loss: 0.1585 - Val Loss: 0.2639 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 40] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [41/100] - Train Loss: 0.1951 - Val Loss: 0.2016 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 41] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [42/100] - Train Loss: 0.1535 - Val Loss: 0.2518 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 42] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [43/100] - Train Loss: 0.1952 - Val Loss: 0.2501 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 43] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [44/100] - Train Loss: 0.1546 - Val Loss: 0.3962 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 44] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [45/100] - Train Loss: 0.1714 - Val Loss: 0.2017 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 45] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [46/100] - Train Loss: 0.1615 - Val Loss: 0.4853 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 46] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [47/100] - Train Loss: 0.1581 - Val Loss: 0.3953 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 47] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [48/100] - Train Loss: 0.1638 - Val Loss: 0.2033 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 48] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [49/100] - Train Loss: 0.1451 - Val Loss: 0.1366 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 49] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [50/100] - Train Loss: 0.1432 - Val Loss: 0.1883 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 50] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [51/100] - Train Loss: 0.1535 - Val Loss: 0.2089 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 51] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [52/100] - Train Loss: 0.1161 - Val Loss: 0.2042 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 52] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [53/100] - Train Loss: 0.1640 - Val Loss: 0.5161 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 53] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [54/100] - Train Loss: 0.1261 - Val Loss: 0.2861 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 54] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [55/100] - Train Loss: 0.1331 - Val Loss: 0.4098 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 55] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [56/100] - Train Loss: 0.1376 - Val Loss: 0.2615 - Val Acc: 0.9000 - Prec: 0.9286 - Recall: 0.8667
# [Epoch 56] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [57/100] - Train Loss: 0.1386 - Val Loss: 0.2421 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 57] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [58/100] - Train Loss: 0.1392 - Val Loss: 0.4652 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 58] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [59/100] - Train Loss: 0.1195 - Val Loss: 0.5011 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 59] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [60/100] - Train Loss: 0.1246 - Val Loss: 0.3394 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 60] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [61/100] - Train Loss: 0.1271 - Val Loss: 0.2359 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 61] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [62/100] - Train Loss: 0.1186 - Val Loss: 0.7394 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 62] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [63/100] - Train Loss: 0.1268 - Val Loss: 0.2535 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 63] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [64/100] - Train Loss: 0.1062 - Val Loss: 0.2127 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 64] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [65/100] - Train Loss: 0.1144 - Val Loss: 0.2235 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 65] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [66/100] - Train Loss: 0.1036 - Val Loss: 0.5211 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 66] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [67/100] - Train Loss: 0.1223 - Val Loss: 0.1838 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 67] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [68/100] - Train Loss: 0.1241 - Val Loss: 0.3640 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 68] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [69/100] - Train Loss: 0.0977 - Val Loss: 0.1351 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 69] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [70/100] - Train Loss: 0.1095 - Val Loss: 0.1218 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 70] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [71/100] - Train Loss: 0.0915 - Val Loss: 0.4358 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 71] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [72/100] - Train Loss: 0.1132 - Val Loss: 0.3758 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 72] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [73/100] - Train Loss: 0.0745 - Val Loss: 0.3577 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 73] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [74/100] - Train Loss: 0.1309 - Val Loss: 0.1749 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 74] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [75/100] - Train Loss: 0.0839 - Val Loss: 0.4307 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 75] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [76/100] - Train Loss: 0.0934 - Val Loss: 0.0392 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 76] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.0392
# Epoch [77/100] - Train Loss: 0.0856 - Val Loss: 0.1438 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 77] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [78/100] - Train Loss: 0.1089 - Val Loss: 0.4267 - Val Acc: 0.9000 - Prec: 1.0000 - Recall: 0.8000
# [Epoch 78] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [79/100] - Train Loss: 0.0850 - Val Loss: 0.2862 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 79] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [80/100] - Train Loss: 0.0849 - Val Loss: 0.1125 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 80] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [81/100] - Train Loss: 0.1160 - Val Loss: 0.0890 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 81] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [82/100] - Train Loss: 0.0914 - Val Loss: 0.0281 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 82] Unique preds: {0, 1}, Unique labels: {0, 1}
# Best model updated! Saved model with val_loss = 0.0281
# Epoch [83/100] - Train Loss: 0.0806 - Val Loss: 0.4138 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 83] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [84/100] - Train Loss: 0.0907 - Val Loss: 0.1395 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 84] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [85/100] - Train Loss: 0.0929 - Val Loss: 0.0319 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 85] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [86/100] - Train Loss: 0.0931 - Val Loss: 0.0371 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 86] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [87/100] - Train Loss: 0.0698 - Val Loss: 0.1050 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 87] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [88/100] - Train Loss: 0.0923 - Val Loss: 0.1522 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 88] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [89/100] - Train Loss: 0.0840 - Val Loss: 0.3264 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 89] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [90/100] - Train Loss: 0.0740 - Val Loss: 0.4110 - Val Acc: 0.9333 - Prec: 1.0000 - Recall: 0.8667
# [Epoch 90] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [91/100] - Train Loss: 0.0693 - Val Loss: 0.0660 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 91] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [92/100] - Train Loss: 0.0785 - Val Loss: 0.0322 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 92] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [93/100] - Train Loss: 0.0627 - Val Loss: 0.2089 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 93] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [94/100] - Train Loss: 0.0904 - Val Loss: 0.0439 - Val Acc: 1.0000 - Prec: 1.0000 - Recall: 1.0000
# [Epoch 94] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [95/100] - Train Loss: 0.0759 - Val Loss: 0.2807 - Val Acc: 0.9333 - Prec: 0.9333 - Recall: 0.9333
# [Epoch 95] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [96/100] - Train Loss: 0.0642 - Val Loss: 0.1775 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 96] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [97/100] - Train Loss: 0.0767 - Val Loss: 0.2614 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 97] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [98/100] - Train Loss: 0.0816 - Val Loss: 0.2623 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 98] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [99/100] - Train Loss: 0.0671 - Val Loss: 0.2332 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 99] Unique preds: {0, 1}, Unique labels: {0, 1}
# Epoch [100/100] - Train Loss: 0.0702 - Val Loss: 0.1641 - Val Acc: 0.9667 - Prec: 1.0000 - Recall: 0.9333
# [Epoch 100] Unique preds: {0, 1}, Unique labels: {0, 1}
# Saved training metrics plot as 'training_metrics.png'
# Model saved as 'final_model.pth'
#
# [ Training Configuration Summary ]
# ╒═══════════════════════╤═══════════════════════════════════════════════════════════════════╕
# │ Parameter             │ Value                                                             │
# ╞═══════════════════════╪═══════════════════════════════════════════════════════════════════╡
# │ Model Architecture    │ UNetClassifier                                                    │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Input Channels        │ 3                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Output Classes        │ 2                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Feature Sizes         │ [256, 512, 1024, 2048, 4096]                                      │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Loss Function         │ FPFNPenalizedCELoss                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ False Negative Weight │ 3.0                                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ False Positive Weight │ 3.0                                                               │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Optimizer             │ Adam                                                              │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Learning Rate         │ 0.001                                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Weight Decay          │ 1e-05                                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Batch Size            │ 4                                                                 │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Epochs                │ Defined later                                                     │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Train Augmentations   │ Resize, RandomHorizontalFlip, RandomRotation, ToTensor, Normalize │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Val/Test Transforms   │ Resize, ToTensor, Normalize                                       │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Normalization Mean    │ [0.485, 0.456, 0.406]                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Normalization Std     │ [0.229, 0.224, 0.225]                                             │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Train Dataset Path    │ /home/bay/codes/unet/xray/train                                   │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Val Dataset Path      │ /home/bay/codes/unet/xray/val                                     │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Test Dataset Path     │ /home/bay/codes/unet/xray/test                                    │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Device                │ cuda                                                              │
# ├───────────────────────┼───────────────────────────────────────────────────────────────────┤
# │ Model Save Path       │ unet_classifier.pth                                               │
# ╘═══════════════════════╧═══════════════════════════════════════════════════════════════════╛
# Model loaded from 'unet_classifier.pth'
#
# [Before Testing]
# Test dataset contains 270 images.
# Test Accuracy: 0.5000 - Precision: 0.0000 - Recall: 0.0000
# [Test Set] Unique preds: {0}, Unique labels: {0, 1}
# Total mislabelled images: 135
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_10.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_100.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_101.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_102.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_103.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_104.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_105.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_106.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_107.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_108.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_109.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_11.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_110.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_111.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_112.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_113.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_114.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_115.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_116.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_117.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_118.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_119.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_12.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_120.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_121.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_122.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_123.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_124.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_125.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_126.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_127.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_128.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_129.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_13.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_130.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_131.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_132.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_133.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_134.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_135.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_14.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_15.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_16.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_17.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_18.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_19.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_2.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_20.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_21.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_22.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_23.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_24.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_25.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_26.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_27.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_28.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_29.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_3.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_30.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_31.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_32.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_33.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_34.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_35.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_36.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_37.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_38.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_39.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_4.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_40.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_41.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_42.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_43.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_44.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_45.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_46.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_47.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_48.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_49.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_5.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_50.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_51.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_52.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_53.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_54.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_55.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_56.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_57.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_58.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_59.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_6.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_60.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_61.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_62.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_63.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_64.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_65.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_66.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_67.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_68.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_69.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_7.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_70.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_71.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_72.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_73.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_74.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_75.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_76.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_77.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_78.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_79.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_8.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_80.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_81.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_82.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_83.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_84.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_85.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_86.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_87.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_88.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_89.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_9.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_90.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_91.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_92.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_93.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_94.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_95.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_96.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_97.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_98.png | True: PNEUMONIA | Pred: NORMAL
# Mislabelled: /home/bay/codes/unet/xray/test/PNEUMONIA/PNEUMONIA_99.png | True: PNEUMONIA | Pred: NORMAL

# %%
from itertools import product
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score

# Define your grid
param_grid = {
    'lr': [1e-3, 1e-4],
    'weight_decay': [0, 1e-5],
    'batch_size': [4, 8]
}

# Get all combinations
all_combinations = list(product(param_grid['lr'], param_grid['weight_decay'], param_grid['batch_size']))

# Example loop over hyperparameter combinations
best_acc = 0.0
best_params = None

for lr, wd, batch_size in all_combinations:
    print(f"\nTrying lr={lr}, weight_decay={wd}, batch_size={batch_size}")

    # Create new model instance
    model = UNetClassifier(in_channels=3, num_classes=2).to(device)

    # Create optimizer with current hyperparams
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

    # Data loaders (re-create with batch_size)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # === Train ===
    model.train()
    for epoch in range(3):  # Use fewer epochs for search speed
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = nn.CrossEntropyLoss()(outputs, labels)
            loss.backward()
            optimizer.step()

    # === Validate ===
    model.eval()
    val_preds, val_labels = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            val_preds.extend(preds.cpu().numpy())
            val_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(val_labels, val_preds)
    print(f"Validation Accuracy: {acc:.4f}")

    if acc > best_acc:
        best_acc = acc
        best_params = {'lr': lr, 'weight_decay': wd, 'batch_size': batch_size}

print(f"\nBest Hyperparameters: {best_params}, Accuracy: {best_acc:.4f}")
# Out:
# Trying lr=0.001, weight_decay=0, batch_size=4
# Validation Accuracy: 0.5625
#
# Trying lr=0.001, weight_decay=0, batch_size=8
# Validation Accuracy: 0.6875
#
# Trying lr=0.001, weight_decay=1e-05, batch_size=4
# Validation Accuracy: 0.8750
#
# Trying lr=0.001, weight_decay=1e-05, batch_size=8
# Validation Accuracy: 0.5625
#
# Trying lr=0.0001, weight_decay=0, batch_size=4
# Validation Accuracy: 0.6250
#
# Trying lr=0.0001, weight_decay=0, batch_size=8
# Validation Accuracy: 0.5000
#
# Trying lr=0.0001, weight_decay=1e-05, batch_size=4
# Validation Accuracy: 0.5000
#
# Trying lr=0.0001, weight_decay=1e-05, batch_size=8
# Validation Accuracy: 0.6875
#
# Best Hyperparameters: {'lr': 0.001, 'weight_decay': 1e-05, 'batch_size': 4}, Accuracy: 0.8750

# %%
fn_weights = [1.0, 3.0, 5.0, 7.0]
fp_weights = [1.0, 2.0, 3.0, 4.0]
def train_and_validate(fn_weight, fp_weight, num_epochs=3):
    model = UNetClassifier(in_channels=3, num_classes=2).to(device)
    criterion = FPFNPenalizedCELoss(fn_weight=fn_weight, fp_weight=fp_weight)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    for epoch in range(num_epochs):
        model.train()
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

    # Validation
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_labels, all_preds

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from tabulate import tabulate

results = []
best_f1 = 0
best_weights = (0, 0)

for fn in fn_weights:
    for fp in fp_weights:
        print(f"Testing fn_weight={fn}, fp_weight={fp}")
        labels, preds = train_and_validate(fn_weight=fn, fp_weight=fp, num_epochs=3)  # use low epochs for speed

        cm = confusion_matrix(labels, preds)
        acc = accuracy_score(labels, preds)
        f1 = f1_score(labels, preds)

        fn_count = cm[1][0]  # false negatives
        fp_count = cm[0][1]  # false positives

        results.append((fn, fp, acc, f1, fn_count, fp_count))

        if f1 > best_f1:
            best_f1 = f1
            best_weights = (fn, fp)
headers = ["FN Weight", "FP Weight", "Accuracy", "F1 Score", "False Negatives", "False Positives"]
print(tabulate(results, headers=headers, tablefmt="fancy_grid"))

print(f"\n🎯 Best Weights: FN={best_weights[0]}, FP={best_weights[1]} (F1 Score = {best_f1:.4f})")
# Out:
# Testing fn_weight=1.0, fp_weight=1.0
# Testing fn_weight=1.0, fp_weight=2.0
# Testing fn_weight=1.0, fp_weight=3.0
# Testing fn_weight=1.0, fp_weight=4.0
# Testing fn_weight=3.0, fp_weight=1.0
# Testing fn_weight=3.0, fp_weight=2.0
# Testing fn_weight=3.0, fp_weight=3.0
# Testing fn_weight=3.0, fp_weight=4.0
# Testing fn_weight=5.0, fp_weight=1.0
# Testing fn_weight=5.0, fp_weight=2.0
# Testing fn_weight=5.0, fp_weight=3.0
# Testing fn_weight=5.0, fp_weight=4.0
# Testing fn_weight=7.0, fp_weight=1.0
# Testing fn_weight=7.0, fp_weight=2.0
# Testing fn_weight=7.0, fp_weight=3.0
# Testing fn_weight=7.0, fp_weight=4.0
# ╒═════════════╤═════════════╤════════════╤════════════╤═══════════════════╤═══════════════════╕
# │   FN Weight │   FP Weight │   Accuracy │   F1 Score │   False Negatives │   False Positives │
# ╞═════════════╪═════════════╪════════════╪════════════╪═══════════════════╪═══════════════════╡
# │           1 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           2 │     0.6875 │   0.761905 │                 0 │                 5 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           3 │     0.75   │   0.75     │                 2 │                 2 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           1 │           4 │     0.625  │   0.727273 │                 0 │                 6 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           2 │     0.75   │   0.777778 │                 1 │                 3 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           3 │     0.75   │   0.8      │                 0 │                 4 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           3 │           4 │     0.5    │   0.666667 │                 0 │                 8 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           1 │     0.5625 │   0.695652 │                 0 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           2 │     0.75   │   0.8      │                 0 │                 4 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           3 │     0.5    │   0.636364 │                 1 │                 7 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           5 │           4 │     0.75   │   0.777778 │                 1 │                 3 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           1 │     0.5    │   0.666667 │                 0 │                 8 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           2 │     0.6875 │   0.761905 │                 0 │                 5 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           3 │     0.625  │   0.727273 │                 0 │                 6 │
# ├─────────────┼─────────────┼────────────┼────────────┼───────────────────┼───────────────────┤
# │           7 │           4 │     0.5625 │   0.695652 │                 0 │                 7 │
# ╘═════════════╧═════════════╧════════════╧════════════╧═══════════════════╧═══════════════════╛
#
# 🎯 Best Weights: FN=3.0, FP=3.0 (F1 Score = 0.8000)
